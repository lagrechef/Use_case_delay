# %% [markdown]
# # DELAY VERIFICATION

# %%
import pandas as pd
import datetime
from datetime import datetime
from tqdm import tqdm

# %% [markdown]
# ## Import the data

# %%
data=pd.read_csv("delays.csv")

# %% [markdown]
# ## Data cleaning

# %%
data.dtypes
# Out:
# datetime      object
# id            object
# carrier       object
# date          object
# connection    object
# arrival       object
# delay         object
# name          object
# dtype: object

# %% [markdown]
# Convert date in datetime

# %%
data["datetime"]=pd.to_datetime(data["datetime"])
data["date"]=pd.to_datetime(data["date"])
data.dtypes
# Out:
# datetime      datetime64[ns]
# id                    object
# carrier               object
# date          datetime64[ns]
# connection            object
# arrival               object
# delay                 object
# name                  object
# dtype: object

# %% [markdown]
# Convert delay in integer value (number of minutes)

# %%
data["delay_old"]=data["delay"]

data["delay"]=data["delay"].apply(lambda x: x.replace(' min', ''))
data["delay"]=pd.to_numeric(data["delay"])
data.dtypes
# Out:
# datetime      datetime64[ns]
# id                    object
# carrier               object
# date          datetime64[ns]
# connection            object
# arrival               object
# delay                  int64
# name                  object
# delay_old             object
# dtype: object

# %% [markdown]
# ID correction

# %%
data["id_old"]=data["id"]

data["id"]=data["id_old"].apply(lambda x:' '.join(x.split()))
data.head()
# Out:
#     datetime                      id             carrier       date  \
# 0 2022-05-16   41002/3 (102) POLONIA       PKP Intercity 2022-05-15
# 1 2022-05-16           91888/9 (102)  Koleje Mazowieckie 2022-05-16
# 2 2022-05-16           21644/5 (102)  Koleje Mazowieckie 2022-05-16
# 3 2022-05-16           19300/1 (102)  Koleje Mazowieckie 2022-05-16
# 4 2022-05-16  38170/1 (102) USTRONIE       PKP Intercity 2022-05-16
#
#                                  connection arrival  delay  \
# 0              Bohumin - Warszawa Wschodnia   21:31    162
# 1              Siedlce - Warszawa Zachodnia   00:15      0
# 2         Radom Główny - Warszawa Wschodnia   00:29      0
# 3  Warszawa Wschodnia - Grodzisk Mazowiecki   00:34      0
# 4                 Kraków Główny - Kołobrzeg   00:55      0
#
#                  name delay_old                  id_old
# 0  Warszawa Zachodnia   162 min   41002/3 (102) POLONIA
# 1  Warszawa Zachodnia     0 min          91888/9 (102)
# 2  Warszawa Zachodnia     0 min          21644/5 (102)
# 3  Warszawa Zachodnia     0 min          19300/1 (102)
# 4  Warszawa Zachodnia     0 min  38170/1 (102) USTRONIE

# %% [markdown]
# New ID creation: 1 ID per travel

# %%
def new_id_pattern(date, id):
    return id+"_"+str(date.day)+'-'+str(date.month)+'-'+str(date.year)+'_'+str(date.hour)+'-'+str(date.minute)


id_list=data["id"].unique()
id_list

new_data=pd.DataFrame(columns=data.columns)
new_data["new_id"]=pd.Series()

for id in tqdm(id_list):
        
    #prepare dataset columns and re-index
    data_id=data[data['id']==id].copy().reset_index()
    data_id["new_id"]=''

    #initialize first line: ind=0
    date_dep=data_id.iloc[0]['datetime']
    data_id.loc[0,'new_id']=new_id_pattern(date_dep, id)

    #loop parameters
    ind=1 #used to loop over the data
    #stop condition of the loop
    if ind==data_id.shape[0]:stop=True
    else:stop=False 

    #loop to create new_ind value for the current ind
    while not stop:
        diff_date=data_id.loc[ind,'datetime']-data_id.loc[ind-1,'datetime'] #date diff between current and previous ind
        
        #case of 2 successives datetime report: same travel => SAME ID
        if diff_date.total_seconds() <=5*60: #multiplied by 60 as we compare in seconds
            data_id.loc[ind,"new_id"]=new_id_pattern(date_dep,id) #set new_ind value for current ind
            ind+=1

        #case of another travel=> ANOTHER ID
        else: 
            date_dep=date_dep=data_id.loc[ind,'datetime'] #set the departure date for the new travel: will be overwritten for each new travel
            data_id.loc[ind,"new_id"]=new_id_pattern(date_dep,id) #set new_ind value for current ind
            ind+=1
        
        #Stop condition
        if ind==data_id.shape[0]:
            stop=True

    new_data=pd.concat([new_data, data_id], ignore_index = True)
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_8816\822593433.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_data["new_id"]=pd.Series()
#   0%|          | 13/7947 [00:05<56:45,  2.33it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 33
#      31 #case of 2 successives datetime report: same travel => SAME ID
#      32 if diff_date.total_seconds() <=5*60: #multiplied by 60 as we compare in seconds
# ---> 33     data_id.loc[ind,"new_id"]=new_id_pattern(date_dep,id) #set new_ind value for current ind
#      34     ind+=1
#      36 #case of another travel=> ANOTHER ID
#      37 else:
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexing.py:712, in _LocationIndexer.__setitem__(self, key, value)
#     710 else:
#     711     key = com.apply_if_callable(key, self.obj)
# --> 712 indexer = self._get_setitem_indexer(key)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexing.py:661, in _LocationIndexer._get_setitem_indexer(self, key)
#     659 if isinstance(key, tuple):
#     660     with suppress(IndexingError):
# --> 661         return self._convert_tuple(key)
#     663 if isinstance(key, range):
#     664     return list(key)
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexing.py:799, in _LocationIndexer._convert_tuple(self, key)
#     797     self._validate_key_length(key)
#     798     for i, k in enumerate(key):
# --> 799         idx = self._convert_to_indexer(k, axis=i)
#     800         keyidx.append(idx)
#     802 return tuple(keyidx)
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexing.py:1255, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1250 if is_scalar(key) or (isinstance(labels, MultiIndex) and is_hashable(key)):
#    1251     # Otherwise get_loc will raise InvalidIndexError
#    1252
#    1253     # if we are a label return me
#    1254     try:
# -> 1255         return labels.get_loc(key)
#    1256     except LookupError:
#    1257         if isinstance(key, tuple) and isinstance(labels, MultiIndex):
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexes\range.py:379, in RangeIndex.get_loc(self, key, method, tolerance)
#     374     return "integer"
#     376 # --------------------------------------------------------------------
#     377 # Indexing Methods
# --> 379 @doc(Int64Index.get_loc)
#     380 def get_loc(self, key, method=None, tolerance=None):
#     381     if method is None and tolerance is None:
#     382         if is_integer(key) or (is_float(key) and key.is_integer()):
#
# KeyboardInterrupt:

# %%
new_data.to_csv("new_data.csv")

# %% [markdown]
# ## Features creation

# %%
data=pd.read_csv("new_data.csv",index_col='index')
data["datetime"]=pd.to_datetime(data["datetime"])
data["date"]=pd.to_datetime(data["date"])
data=data.drop(columns=["Unnamed: 0"])
data
# Out:
#                    datetime                                    id  \
# index
# 0       2022-05-16 00:00:00   41002/3 (102) POLONIA_16-5-2022_0-0
# 1       2022-05-16 00:00:00           91888/9 (102)_16-5-2022_0-0
# 2       2022-05-16 00:00:00           21644/5 (102)_16-5-2022_0-0
# 3       2022-05-16 00:00:00           19300/1 (102)_16-5-2022_0-0
# 4       2022-05-16 00:00:00  38170/1 (102) USTRONIE_16-5-2022_0-0
# ...                     ...                                   ...
# 3718165 2022-05-29 23:55:00       53172/3 ROZEWIE_29-5-2022_21-35
# 3718166 2022-05-29 23:55:00                 15417_29-5-2022_23-15
# 3718167 2022-05-29 23:55:00      38170/1 USTRONIE_29-5-2022_19-35
# 3718168 2022-05-29 23:55:00      83170/1 USTRONIE_29-5-2022_20-35
# 3718169 2022-05-29 23:55:00       35170/1 KARPATY_29-5-2022_23-35
#
#                     carrier       date  \
# index
# 0             PKP Intercity 2022-05-15
# 1        Koleje Mazowieckie 2022-05-16
# 2        Koleje Mazowieckie 2022-05-16
# 3        Koleje Mazowieckie 2022-05-16
# 4             PKP Intercity 2022-05-16
# ...                     ...        ...
# 3718165       PKP Intercity 2022-05-30
# 3718166  Koleje Mazowieckie 2022-05-30
# 3718167       PKP Intercity 2022-05-30
# 3718168       PKP Intercity 2022-05-30
# 3718169       PKP Intercity 2022-05-30
#
#                                        connection arrival  delay  \
# index
# 0                    Bohumin - Warszawa Wschodnia   21:31    162
# 1                    Siedlce - Warszawa Zachodnia   00:15      0
# 2               Radom Główny - Warszawa Wschodnia   00:29      0
# 3        Warszawa Wschodnia - Grodzisk Mazowiecki   00:34      0
# 4                       Kraków Główny - Kołobrzeg   00:55      0
# ...                                           ...     ...    ...
# 3718165             Gdynia Główna - Kraków Główny   07:25      4
# 3718166        Warszawa Zachodnia peron 9 - Mława   00:23      0
# 3718167                 Kraków Główny - Kołobrzeg   02:16      0
# 3718168                 Kołobrzeg - Kraków Główny   03:17      6
# 3718169             Kraków Główny - Gdynia Główna   05:16      0
#
#                          name delay_old                  id_old  final_delay
# index
# 0          Warszawa Zachodnia   162 min   41002/3 (102) POLONIA          NaN
# 1          Warszawa Zachodnia     0 min          91888/9 (102)           NaN
# 2          Warszawa Zachodnia     0 min          21644/5 (102)           NaN
# 3          Warszawa Zachodnia     0 min          19300/1 (102)           NaN
# 4          Warszawa Zachodnia     0 min  38170/1 (102) USTRONIE          NaN
# ...                       ...       ...                     ...          ...
# 3718165             Mysłowice     4 min        53172/3  ROZEWIE          NaN
# 3718166  Nowy Dwór Mazowiecki     0 min                 15417            NaN
# 3718167  Nowy Dwór Mazowiecki     0 min       38170/1  USTRONIE          NaN
# 3718168  Nowy Dwór Mazowiecki     6 min       83170/1  USTRONIE          NaN
# 3718169  Nowy Dwór Mazowiecki     0 min        35170/1  KARPATY          NaN
#
# [3718170 rows x 11 columns]

# %%
dd=data.loc[data.groupby('id')["delay"].idxmax()]
dd[dd["delay"]>0]
# Out:
#                    datetime                                      id  \
# index
# 1065463 2022-05-19 19:55:00  10102/3 (130) ZAMENHOF_19-5-2022_19-55
# 1830753 2022-05-22 19:55:00  10102/3 (130) ZAMENHOF_22-5-2022_19-55
# 240841  2022-05-16 20:00:00    10102/3 (49) ZAMENHOF_16-5-2022_20-0
# 1589499 2022-05-21 19:35:00   10102/3 (49) ZAMENHOF_21-5-2022_19-35
# 1831704 2022-05-22 20:00:00    10102/3 (49) ZAMENHOF_22-5-2022_20-0
# ...                     ...                                     ...
# 1096201 2022-05-19 22:55:00                 99972/3_19-5-2022_22-15
# 1382156 2022-05-20 23:35:00                 99972/3_20-5-2022_23-35
# 547714  2022-05-17 23:35:00           99990/1 (117)_17-5-2022_22-55
# 548789  2022-05-17 23:55:00           99990/1 (117)_17-5-2022_23-50
# 548017  2022-05-17 23:35:00                 99990/1_17-5-2022_23-35
#
#                carrier       date  \
# index
# 1065463  PKP Intercity 2022-05-19
# 1830753  PKP Intercity 2022-05-22
# 240841   PKP Intercity 2022-05-16
# 1589499  PKP Intercity 2022-05-21
# 1831704  PKP Intercity 2022-05-22
# ...                ...        ...
# 1096201   SKM Warszawa 2022-05-19
# 1382156   SKM Warszawa 2022-05-20
# 547714    SKM Warszawa 2022-05-17
# 548789    SKM Warszawa 2022-05-17
# 548017    SKM Warszawa 2022-05-17
#
#                                             connection arrival  delay  \
# index
# 1065463                 Warszawa Zachodnia - Białystok   20:18     23
# 1830753                 Warszawa Zachodnia - Białystok   20:18      7
# 240841                  Warszawa Zachodnia - Białystok   20:30      7
# 1589499                 Warszawa Zachodnia - Białystok   20:18      5
# 1831704                 Warszawa Zachodnia - Białystok   20:30      7
# ...                                                ...     ...    ...
# 1096201  Sulejówek Miłosna - Warszawa Lotnisko Chopina   23:02      1
# 1382156  Sulejówek Miłosna - Warszawa Lotnisko Chopina   23:20     18
# 547714          Sulejówek Miłosna - Warszawa Zachodnia   23:26     18
# 548789          Sulejówek Miłosna - Warszawa Zachodnia   23:42     20
# 548017          Sulejówek Miłosna - Warszawa Zachodnia   23:18     20
#
#                        name delay_old                  id_old  final_delay
# index
# 1065463  Warszawa Centralna    23 min  10102/3 (130) ZAMENHOF          NaN
# 1830753  Warszawa Centralna     7 min  10102/3 (130) ZAMENHOF          NaN
# 240841   Warszawa Wschodnia     7 min   10102/3 (49) ZAMENHOF          NaN
# 1589499  Warszawa Centralna     5 min   10102/3 (49) ZAMENHOF          NaN
# 1831704  Warszawa Wschodnia     7 min   10102/3 (49) ZAMENHOF          NaN
# ...                     ...       ...                     ...          ...
# 1096201     Warszawa Ochota     1 min               99972/3            NaN
# 1382156  Warszawa Służewiec    18 min               99972/3            NaN
# 547714   Warszawa Wschodnia    18 min          99990/1 (117)           NaN
# 548789   Warszawa Zachodnia    20 min          99990/1 (117)           NaN
# 548017   Warszawa Rembertów    20 min               99990/1            NaN
#
# [33495 rows x 11 columns]

# %%
data[data["id"]=="10102/3 (130) ZAMENHOF_19-5-2022_19-55"]
# Out:
#                    datetime                                      id  \
# index
# 1065463 2022-05-19 19:55:00  10102/3 (130) ZAMENHOF_19-5-2022_19-55
#
#                carrier       date                      connection arrival  \
# index
# 1065463  PKP Intercity 2022-05-19  Warszawa Zachodnia - Białystok   20:18
#
#          delay                name delay_old                  id_old  \
# index
# 1065463     23  Warszawa Centralna    23 min  10102/3 (130) ZAMENHOF
#
#          final_delay
# index
# 1065463          NaN

# %% [markdown]
# Target value: final value of delay

# %%
dd=data[data['id_old']=="10102/3 (130) ZAMENHOF"]
dd[dd['date']=='2022-05-17']
# Out:
#                   datetime                                      id  \
# index
# 513901 2022-05-17 19:55:00  10102/3 (130) ZAMENHOF_17-5-2022_19-55
# 516102 2022-05-17 20:05:00   10102/3 (130) ZAMENHOF_17-5-2022_20-5
#
#               carrier       date                      connection arrival  \
# index
# 513901  PKP Intercity 2022-05-17  Warszawa Zachodnia - Białystok   20:18
# 516102  PKP Intercity 2022-05-17  Warszawa Zachodnia - Białystok   20:30
#
#         delay                name delay_old                  id_old  \
# index
# 513901      0  Warszawa Centralna     0 min  10102/3 (130) ZAMENHOF
# 516102      0  Warszawa Wschodnia     0 min  10102/3 (130) ZAMENHOF
#
#         final_delay
# index
# 513901          NaN
# 516102          NaN

# %% [markdown]
# Number of delays a day

# %%
id=id_list[0]
data[data["id"]==id].reset_index().loc[data[data["id"]==id].shape[0], 'delay']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 19 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 2
#       1 id=id_list[0]
# ----> 2 data[data["id"]==id].reset_index().loc[data[data["id"]==id].shape[0], 'delay']
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File c:\Users\louis\anaconda3\envs\projet_use_case\lib\site-packages\pandas\core\indexes\range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 19

# %%
data[data["id"]=="31100/1 (102) MALINOWSKI"]
# Out:
#      datetime                        id        carrier       date  \
# 45 2022-05-16  31100/1 (102) MALINOWSKI  PKP Intercity 2022-05-15
#
#                               connection arrival  delay                name  \
# 45  Przemyśl Główny - Warszawa Wschodnia   23:31     34  Warszawa Wschodnia
#
#    delay_old                    id_old
# 45    34 min  31100/1 (102) MALINOWSKI

# %%
print(data["id"].iloc[3718078])
' '.join(data["id"].iloc[3718078].split())
r
# Out:
# 53172/3  ROZEWIE
# '53172/3 ROZEWIE'
